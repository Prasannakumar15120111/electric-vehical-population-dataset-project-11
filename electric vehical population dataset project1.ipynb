# %% [markdown]
# # Project Title: electric vehical population dataset project1
#
# ## Purpose
# The project titled "Electric Vehicle Population Dataset Analysis" aims to leverage Python libraries such as pandas and matplotlib to analyze a dataset containing information about electric vehicle (EV) populations. Using pandas, the project will explore and manipulate the dataset, examining factors such as the total number of EVs, types of EVs, geographic distribution of EV ownership, and trends over time. Matplotlib will be used to create visualizations, including histograms, pie charts, and geographical plots, to convey insights and patterns within the EV dataset. The goal is to generate actionable insights that can inform decision-making related to EV adoption and policies. This analysis will provide a comprehensive understanding of the current state and trends of EV usage based on the dataset.

# %%
#importing the necessary packages for data manipulation and visulation
import pandas as pd 
import matplotlib as mpl

# %% [markdown]
# # step 2: Load the files

# %%
#Reading the CSV file into a Dataframe
data = pd.read_csv('Electric_Vehicle_Population_Data.csv')
print(data)
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %% [markdown]
# ## step 3: Data view

# %%
# displays the first few rows
data.head()
# Out:
#    VIN (1-10)     County       City State  Postal Code  Model Year   Make  \
# 0  5YJYGDEE1L       King    Seattle    WA      98122.0        2020  TESLA
# 1  7SAYGDEE9P  Snohomish    Bothell    WA      98021.0        2023  TESLA
# 2  5YJSA1E4XK       King    Seattle    WA      98109.0        2019  TESLA
# 3  5YJSA1E27G       King   Issaquah    WA      98027.0        2016  TESLA
# 4  5YJYGDEE5M     Kitsap  Suquamish    WA      98392.0        2021  TESLA
#
#      Model           Electric Vehicle Type  \
# 0  MODEL Y  Battery Electric Vehicle (BEV)
# 1  MODEL Y  Battery Electric Vehicle (BEV)
# 2  MODEL S  Battery Electric Vehicle (BEV)
# 3  MODEL S  Battery Electric Vehicle (BEV)
# 4  MODEL Y  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 1  Eligibility unknown as battery range has not b...               0
# ...

# %%
#It returns a pandas Index object containing the column labels
data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
# It will display a concise summary of the DataFrame
data.info
# Out:
# <bound method DataFrame.info of         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
#prints the shape 
data.shape
# Out:
# (177866, 17)

# %%
#displays the datatypes 
data.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %% [markdown]
# ## step 4: Data cleaning/ Manipulation(Filteration)

# %%
#count the number of non-null values in each column of a DataFrame.
data.count
# Out:
# <bound method DataFrame.count of         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
#counts the occurrences of unique values in a Series or DataFrame column.
data.value_counts
# Out:
# <bound method DataFrame.value_counts of         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
#obtains an array of unique values from a specific column 'City'  of a DataFrame. 
data['City'].unique()
# Out:
# array(['Seattle', 'Bothell', 'Issaquah', 'Suquamish', 'Yelm', 'Yakima',
#        'Port Orchard', 'Auburn', 'Bainbridge Island', 'Lynnwood',
#        'Olympia', 'Renton', 'Tenino', 'Lacey', 'Brier', 'Shoreline',
#        'Rochester', 'Coupeville', 'Marysville', 'Pacific', 'Everett',
#        'Edmonds', 'Wenatchee', 'Kingston', 'Mukilteo', 'Anacortes',
#        'Bremerton', 'Snohomish', 'Spokane', 'Oak Harbor', 'Walla Walla',
#        'Mill Creek', 'Moses Lake', 'Ephrata', 'Monroe', 'Moxee', 'Olalla',
#        'Chewelah', 'Freeland', 'Pullman', 'Ellensburg', 'Naches',
#        'Kettle Falls', 'Chelan', 'Quincy', 'Clinton', 'Burien',
#        'Cashmere', 'Poulsbo', 'Vashon', 'Langley', 'Newport',
#        'Ravensdale', 'Cle Elum', 'Redmond', 'Mount Vernon', 'Kent',
#        'Vancouver', 'Bellevue', 'Kirkland', 'Tukwila', 'Federal Way',
#        'Seabeck', 'North Bend', 'Duvall', 'Woodinville', 'Sammamish',
#        'Brush Prairie', 'Castle Rock', 'La Center', 'Camas', 'Silverdale',
# ...

# %%
#displace the total number of rows and columns
data.shape
# Out:
# (177866, 17)

# %%
# Remove rows with any missing values 
data.dropna()
# Out:
#         VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King        Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish        Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King        Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King       Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap      Suquamish    WA      98392.0        2021
# ...            ...        ...            ...   ...          ...         ...
# 177861  7SAYGDEE3N     Pierce    Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason        Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant         Quincy    WA      98848.0        2021
# 177864  WVGKMPE27M       King  Black Diamond    WA      98010.0        2021
# 177865  5YJ3E1EA8M     Pierce         Tacoma    WA      98422.0        2021
#
# ...

# %%
#displays the shape
data.shape
# Out:
# (177866, 17)

# %%
data.shape
# Out:
# (177866, 17)

# %%
#checks the row if any null value replaces with true
data.dropna(inplace=True)

# %%
# Identify duplicates in the 'City' column
data['City'].duplicated()
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 177861     True
# 177862     True
# 177863     True
# 177864     True
# 177865     True
# Name: City, Length: 177473, dtype: bool

# %%
#removes the duplicatess from the Dataframe
data.drop_duplicates(inplace=True)

# %%
#It will diplays the sum of duplicates
duplicate_rows = data.duplicated()
print(duplicate_rows.sum())
# Out:
# 0

# %% [markdown]
# ## Step 5:  Data Sorting / Searching / validations

# %%
#displays the column 'model year'
data['DOL Vehicle ID']
# Out:
# 0         125701579
# 1         244285107
# 2         156773144
# 3         165103011
# 4         205138552
#             ...
# 177861    195224452
# 177862    228454180
# 177863    168797219
# 177864    182448801
# 177865    211464683
# Name: DOL Vehicle ID, Length: 177473, dtype: int64

# %%
# sort the data in ascending order
data.sort_values('Model Year',ascending=True)
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 160817  1GCDE14HXV  Snohomish    Marysville    WA      98270.0        1997
# 49390   1FTZR1078W    Clallam        Sequim    WA      98382.0        1998
# 121373  1FTZR0812X     Skagit  Mount Vernon    WA      98274.0        1999
# 167960  1FTZR0813X     Pierce        Graham    WA      98338.0        1999
# 157465  1FTZR0819X    Whatcom        Deming    WA      98244.0        1999
# ...            ...        ...           ...   ...          ...         ...
# 16993   1C4RJXP66R       King       Seattle    WA      98104.0        2024
# 97060   7SAYGDEE8R       King        Duvall    WA      98019.0        2024
# 60725   YSMFD3KA7R       King       Seattle    WA      98121.0        2024
# 97041   KNDAFFS51R     Pierce   Bonney Lake    WA      98391.0        2024
# 109822  WB523CF08R  Snohomish       Bothell    WA      98012.0        2024
#
# ...

# %%
# sort the data in the decending order 
data.sort_values('Electric Range',ascending=False)
# Out:
#         VIN (1-10)     County            City State  Postal Code  Model Year  \
# 111532  5YJSA1E46L    Spokane         Spokane    WA      99208.0        2020
# 83202   5YJSA1E49L       King        Kirkland    WA      98034.0        2020
# 127486  5YJSA1E4XL     Pierce      Gig Harbor    WA      98335.0        2020
# 124256  5YJSA1E43L    Spokane  Spokane Valley    WA      99016.0        2020
# 21429   5YJSA1E40L       King       Shoreline    WA      98177.0        2020
# ...            ...        ...             ...   ...          ...         ...
# 86285   5YJYGDEE7M  Snohomish   Granite Falls    WA      98252.0        2021
# 86284   7SAYGDEE4P   Thurston           Lacey    WA      98513.0        2023
# 86282   5YJYGDEE3M     Pierce      Gig Harbor    WA      98332.0        2021
# 11112   WVGJNPE22N       King        Kirkland    WA      98034.0        2022
# 177865  5YJ3E1EA8M     Pierce          Tacoma    WA      98422.0        2021
#
# ...

# %%
#displays the data of range > 30
data['Electric Range']>30
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 177861    False
# 177862    False
# 177863    False
# 177864    False
# 177865    False
# Name: Electric Range, Length: 177473, dtype: bool

# %%
# Filter rows where City is 'Gig Harbor' or 'Shoreline'
data[data['City'].isin(['Gig Harbor', 'Shoreline'])]
# Out:
#         VIN (1-10)  County        City State  Postal Code  Model Year  \
# 39      1N4AZ0CP1D    King   Shoreline    WA      98155.0        2013
# 225     JTDKN3DP5F    King   Shoreline    WA      98155.0        2015
# 260     7SAYGDEE9P    King   Shoreline    WA      98133.0        2023
# 265     7SAYGDEE0R    King   Shoreline    WA      98155.0        2024
# 301     1G1FY6S08P    King   Shoreline    WA      98133.0        2023
# ...            ...     ...         ...   ...          ...         ...
# 177481  5YJ3E1EAXP  Pierce  Gig Harbor    WA      98335.0        2023
# 177483  KL8CK6S00E    King   Shoreline    WA      98155.0        2014
# 177605  5YJSA1DP4D  Pierce  Gig Harbor    WA      98335.0        2013
# 177710  5YJYGDEE5M  Pierce  Gig Harbor    WA      98335.0        2021
# 177722  YV4ED3GL6P  Pierce  Gig Harbor    WA      98335.0        2023
#
#              Make          Model                   Electric Vehicle Type  \
# ...

# %%
# Filter rows where Name length is greater than 4 characters
data[data['Model'].apply(lambda x: len(x) > 4)]
# Out:
#         VIN (1-10)     County         City State  Postal Code  Model Year  \
# 0       5YJYGDEE1L       King      Seattle    WA      98122.0        2020
# 1       7SAYGDEE9P  Snohomish      Bothell    WA      98021.0        2023
# 2       5YJSA1E4XK       King      Seattle    WA      98109.0        2019
# 3       5YJSA1E27G       King     Issaquah    WA      98027.0        2016
# 4       5YJYGDEE5M     Kitsap    Suquamish    WA      98392.0        2021
# ...            ...        ...          ...   ...          ...         ...
# 177860  1G1FX6S00J    Clallam       Sequim    WA      98382.0        2018
# 177861  7SAYGDEE3N     Pierce  Bonney Lake    WA      98391.0        2022
# 177862  KM8K23AG1P      Mason      Shelton    WA      98584.0        2023
# 177863  5YJYGDEE6M      Grant       Quincy    WA      98848.0        2021
# 177865  5YJ3E1EA8M     Pierce       Tacoma    WA      98422.0        2021
#
#              Make          Model           Electric Vehicle Type  \
# ...

# %%
# Filter rows where City is 'Seattle' and Electric Range is greater than 200(loc[] for label-based indexing)
data.loc[(df['City'] == 'Seattle') & (data['Electric Range'] > 200)]
# Out:
#     VIN (1-10) County     City State  Postal Code  Model Year   Make    Model  \
# 0   5YJYGDEE1L   King  Seattle    WA      98122.0        2020  TESLA  MODEL Y
# 2   5YJSA1E4XK   King  Seattle    WA      98109.0        2019  TESLA  MODEL S
# 10  5YJYGDEEXL   King  Seattle    WA      98144.0        2020  TESLA  MODEL Y
# 18  5YJ3E1EB4L   King  Seattle    WA      98126.0        2020  TESLA  MODEL 3
#
#              Electric Vehicle Type  \
# 0   Battery Electric Vehicle (BEV)
# 2   Battery Electric Vehicle (BEV)
# 10  Battery Electric Vehicle (BEV)
# 18  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             291
# 2            Clean Alternative Fuel Vehicle Eligible             270
# 10           Clean Alternative Fuel Vehicle Eligible             291
# 18           Clean Alternative Fuel Vehicle Eligible             322
#
# ...

# %% [markdown]
# ## Data visualitation

# %%
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
#train the data
df = pd.DataFrame(data)

# %%
#Generate the pie chart
df = pd.DataFrame(data.head(20))
df['Model Year'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title("Model")
plt.show()

# %%
df = pd.DataFrame(data.head(20))
df['Electric Range'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title("Model")
plt.show()

# %%
#generate the Bar chat
df = pd.DataFrame(data.head(20))
df['Model Year'].value_counts().plot(kind='bar',color='skyblue')
plt.xlabel('Model Year')
plt.ylabel('count')
plt.title("Model")
plt.show()

# %%
#bar graph
df = pd.DataFrame(data.head(20))
df['Electric Vehicle Type'].value_counts().plot(kind='bar',color='Green')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Count')
plt.title("Count of Electric Vehicle Types")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %%
#histogram
df = pd.DataFrame(data.head(20))
df['Electric Range'].value_counts().plot(kind='hist',color='blue',bins=10)
plt.xlabel('Electric Range')
plt.ylabel('Frequency')
plt.title("Distribution of Electric Range")
#plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#line graph
df = pd.DataFrame(data.head(20))
df['Electric Range'].plot(kind='line', color='red', marker='o', linestyle='-')
plt.xlabel('Vehicle Index')
plt.ylabel('Electric Range')
plt.title("Electric Range of Vehicles")
plt.grid(True)
plt.xticks(df.index, df['VIN (1-10)'])  # Use VIN as x-axis labels
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(data.head(20))
plt.figure(figsize=(8, 6))
df['Model Year'].plot(kind='line', color='red', marker='o', linestyle='-')
plt.xlabel('Model Year')
plt.xlabel('2020 Census Tract')
plt.title("Model year vs census tract")
plt.show()

# %%
#generate the scatter plot
df = pd.DataFrame(data.head(30))
plt.scatter(df.index, df['Model Year'],df['Electric Range'], alpha=0.7, edgecolors='black')
plt.title('Electric Range vs Model Year')
plt.xlabel('Electric Range')
plt.ylabel('Model Year')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#generate the scatter plot
df = pd.DataFrame(data.head(30))
plt.scatter(df.index, df['Base MSRP'],df['Electric Range'], alpha=0.7, edgecolors='black')
plt.title('Electric Range vs Base MSRP')
plt.xlabel('Base MSRP')
plt.ylabel('Electric Range')
plt.tight_layout()
plt.show()
